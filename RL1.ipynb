# %% [markdown]
# <a href="https://colab.research.google.com/github/shashwatverma81/Python_RL/blob/main/RL1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random.seed(1)

# %%
# 1000 random integers between 0 and 50
x = np.random.randint(0,50,1000)

# %%
y = x + np.random.randint(0, 50, 1000)
print(x)
# Out:
# [37 43 12  8  9 11  5 15  0 16  1 12  7 45  6 25 20 37 18 20 11 42 28 29
#  14  4 23 23 41 49 30 32 22 13 41  9  7 22  1  0 17  8 24 13 47 42  8 30
#   7  3  6 21 49  3  4 24 49 43 12 26 16 45 41 18 15  0  4 25 47 34 23  7
#  26 25 40 22  9  3 39 23 36 27 37 19 38  8 32 34 10 23 15 47 23 25  7 28
#  10 46 32 24 23  1 49 13  3  0 13  6 21  6  2 12 27 21 11  7 13  8 11 12
#  43 20 30 36 39  7 45  4 48 18 32 13 10 23 17  7 24 10 28 20 32 12  1 30
#  41 24 18 33  2 44 28 39 34 10 32 41 18 22  6  2  7 39 48 15  5 17 42 20
#  48 22 37 13 49 33 20 10 32 25 21 39 32 19 25 49 14 13 20 43  6 13 15 24
#   9  2  7  5 36 37 21 40 13 27 49 49 47 13 40 14 45 23 16 28 42 45  3  2
#  14 46  0 29 11 35 29 33  2 20 19 48 32 28 18 31 28 30 10  8 45 35 32  8
#  20 13 15 41  0 44 19 24 49 42 20 44 15 30 27 14 19 26 43 22  7 35 47 46
#  34 36 36 32 19  3 24 19 37 30 38 47 39  5 15 49 23 32 42 10  2 24 34 30
#  17  4  0 14 17 39 35 17 28 22 38 41 10 13  6 25 38 48 48 44 41  0 22 16
# ...

# %%
y = x + np.random.normal(0,10,1000)
print(y)
# Out:
# [ 15.2787729   44.90387237  -2.05227544  11.69860474   6.38218304
#    2.67286487 -10.5378261    8.17152156   3.1062382   14.74552806
#    7.66243799   4.11669731  23.05993522  42.62046584  -2.45195429
#   38.10159231  33.57566478  36.09830683  13.15697883  29.10074639
#    2.05863032  51.35191542  14.1281948   28.16606727  14.11755507
#   16.08099461   4.70780366  25.34436722  39.79289533  49.02908287
#   21.15894454  18.9810517   17.36862938  10.58336215  55.75183478
#   10.11381644   6.95723745  28.98346293 -15.11854641   7.22566447
#   26.15376141  17.07143868  20.67005938   0.64750004  37.15071494
#   44.47453869  13.36764845  42.76549776  22.21434045  11.71248281
#    6.33928798  23.64919957  46.6468763   13.54868452   9.94271549
#   26.15859672  36.44399462  53.46661385  -3.26886366  38.31782187
#   25.84629504  29.1293118   40.51535664   5.5860574   13.5538068
#    5.55169974   2.633619    11.36131975  49.60827277  36.59487707
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
y = x - np.random.randint(0, 50, 1000)
print(x)
# Out:
# [37 43 12  8  9 11  5 15  0 16  1 12  7 45  6 25 20 37 18 20 11 42 28 29
#  14  4 23 23 41 49 30 32 22 13 41  9  7 22  1  0 17  8 24 13 47 42  8 30
#   7  3  6 21 49  3  4 24 49 43 12 26 16 45 41 18 15  0  4 25 47 34 23  7
#  26 25 40 22  9  3 39 23 36 27 37 19 38  8 32 34 10 23 15 47 23 25  7 28
#  10 46 32 24 23  1 49 13  3  0 13  6 21  6  2 12 27 21 11  7 13  8 11 12
#  43 20 30 36 39  7 45  4 48 18 32 13 10 23 17  7 24 10 28 20 32 12  1 30
#  41 24 18 33  2 44 28 39 34 10 32 41 18 22  6  2  7 39 48 15  5 17 42 20
#  48 22 37 13 49 33 20 10 32 25 21 39 32 19 25 49 14 13 20 43  6 13 15 24
#   9  2  7  5 36 37 21 40 13 27 49 49 47 13 40 14 45 23 16 28 42 45  3  2
#  14 46  0 29 11 35 29 33  2 20 19 48 32 28 18 31 28 30 10  8 45 35 32  8
#  20 13 15 41  0 44 19 24 49 42 20 44 15 30 27 14 19 26 43 22  7 35 47 46
#  34 36 36 32 19  3 24 19 37 30 38 47 39  5 15 49 23 32 42 10  2 24 34 30
#  17  4  0 14 17 39 35 17 28 22 38 41 10 13  6 25 38 48 48 44 41  0 22 16
# ...

# %%
y = x + np.random.normal(0,10,1000)
print(y)
# Out:
# [ 3.33170003e+01  3.61292935e+01  2.72395162e+01 -8.73078224e+00
#   1.25697214e+00  1.61062184e+01  1.27313912e+01  2.08967813e+01
#   1.03516597e+01  2.12094691e+01 -1.37051193e+01  3.89302980e+01
#   8.54123653e+00  2.39075278e+01 -2.00767690e+00  1.99789581e+01
#   1.98451615e+01  1.67479554e+01  2.88626413e+01  2.57758813e+01
#   2.27934064e+01  4.57729612e+01  2.59054317e+01  9.65018367e+00
#   1.72599132e+01  5.28479937e+00  2.48344103e+01  2.84357981e+00
#   4.16935018e+01  6.00944919e+01  3.24660206e+01  3.20916265e+01
#   4.22041520e+01  2.01662676e+01  4.14052203e+01  1.49740295e+01
#   6.06195954e+00  2.26055852e+01 -2.51461157e+00 -8.43100785e+00
#   1.30961071e+01  1.75142302e+01  1.75600432e+01  5.50971210e+00
#   5.00719026e+01  4.40901141e+01  1.36079877e+00  2.83451357e+01
#   6.66862495e-01  1.19306724e+01  8.20751832e+00  3.23992219e+01
#   4.36331529e+01 -9.73960950e+00  1.01228757e+01  3.10738876e+01
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
# 1000 random integers between 0 and 50
x = np.random.randint(0,50,1000)
# negative correlation with some noise
y = 100 - x + np.random.normal(0,5,1000)
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.94491024],
#        [-0.94491024,  1.        ]])

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
z = np.random.randint(0,50,1000)
e = np.random.randint(0,50,1000)
e = z + np.random.randint(50, 100, 1000)
print(z)
print(e)
# Out:
# [37 25 19 10 11  8 49  6  2 26 40 29 36 19 47 17 37 41  1 11 43 49 29 18
#   8 24 14 22 28 45 36 46 14 28 46 15  6 37 30 11 11 20 35 26 21  8 44  3
#  42 30 12 43  6 22 16 40  2 23  1 22 10 32 33 14 33 11  2 36 36 26 44 39
#  33 26  1 29 30 37 36  2 23 18 23  0 37 46 15 44 11  9  8  4 22 21 48 48
#  14 36  7 21  5 25 35 41 47 35 21 23  3  6 40 41 41 21 38 41 36 18 32 27
#  21 35  3 11 43 41 12 20 28  6 13 18 27 24  7 35 17 12 28 31 26 17 13 33
#   7 22 16  1  1  7 31 30 34 42 38 39 24 14 44 46 19 34 31 44 30 42 20 33
#  30 47  6  5 17 29 31 10 19 27 40 15 29 31 28 22 44 27 23 40 14 42 21 43
#  15 47 19 33 47 36  9 15 39 49  1 11 46 47  3 14 48  0  8 42  5  0 36 27
#   4 12 42 10 27 46 37 35 27 27  0 18 34 47 45 16 27 37 43  0 23  5  4 41
#  29 41 36 29 12 40 26 10 43 11 20 41 38  0  5 35  6 30 39 34 30 46 13 37
#  48 26  3 47 41 17 23  0  6 45  3  0  4 45 48 46  8 46 29  3 46 33 22 46
#  15 39  7  3 17  3 44 19 41 34  5 32 34 17 47 24  8 18 13  5 36  5 29 32
# ...

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(z,e)
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({'a' : np.random.randint(0,50,1000)})
df['b']=df['a']+np.random.normal(0,50,1000)
df['c']=100-df['a']+np.random.normal(0,50,1000)
df['d']=np.random.randint(0,50,1000)
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.323018 -0.287650 -0.003566
# b  0.323018  1.000000 -0.106656 -0.003364
# c -0.287650 -0.106656  1.000000 -0.023730
# d -0.003566 -0.003364 -0.023730  1.000000

# %%
pd.plotting.scatter_matrix(df,fingsize=(6,6))
plot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-d7da47ec4e87> in <cell line: 1>()
# ----> 1 pd.plotting.scatter_matrix(df,fingsize=(6,6))
#       2 plot.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     158     """
#     159     plot_backend = _get_plot_backend("matplotlib")
# --> 160     return plot_backend.scatter_matrix(
#     161         frame=frame,
#     162         alpha=alpha,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      95                 common = (mask[a] & mask[b]).values
#      96
# ---> 97                 ax.scatter(
# ...

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns))),df.columns
# Out:
# (([<matplotlib.axis.XTick at 0x7cf49d14e890>,
# ...
#   [Text(0, 1, '0'), Text(1, 1, '1'), Text(2, 1, '2'), Text(3, 1, '3')]),
#  Index(['a', 'b', 'c', 'd'], dtype='object'))
